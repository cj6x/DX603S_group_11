# %% [markdown]
# # Project Final Report
#
# ### Due: 11:59pm on August 9th (with a two hour + one minute grace period) — 50 points
#
# ### No late submissions will be accepted.
#
#
# Complete all sections of this notebook to document your final decisions, results, and broader context.
#
# You will write a **technical report** following standard conventions. Useful references include:
# - [CMU guide to structure](https://www.stat.cmu.edu/~brian/701/notes/paper-structure.pdf)
# - [Data science report example](https://www.projectpro.io/article/data-science-project-report/620)
# - The Checklist in this week’s Blackboard Lesson (aligned with HOML)
#
# Your audience is **technically literate but unfamiliar with your work**—for example, your manager or other data scientists. Your report should be clear, precise, and well-organized, combining explanation, visualizations, and interpretation.
#
# This Final Report is distinct from Milestone 2:
#
# - **Milestone 2** serves as a repository of your working code and experiments
# - **This Final Report** presents a clear, structured summary of your project for a professional audience
#
# > **Important:**
# > - Do **not** assume that readers of this report are familiar with Milestone 2. Your report should stand on its own.
# > - Do not include code, code screenshots, or code cells in this notebook. All code was submitted in Milestone 2. This report should focus on explanation, results, and interpretation.
# > - **Do not add, delete, or move cells in this notebook.** Each answer must be written entirely within its assigned Markdown cell.
# > - All answers should be inserted directly under the appropriate `Answer:` prompt. Delete the sentence "Replace this sentence with your answer in this cell--do not add additional cells" and replace it with your response.
# > - You may use any appropriate Markdown formatting (paragraphs, lists, tables, inserted graphics, LaTeX, etc.).
# > - Submit this notebook as a group via your team leader’s Gradescope account.
#
#
#
#
# ## Submission Checklist
#
# - Final Report Notebook — submitted by team leader
# - **DO NOT SUBMIT Word or PDF files!**

# %% [markdown]
# ## 1. Executive Summary [4 points]
#
# Write a 300–400 word executive summary for a **non-technical audience**, such as business stakeholders in a real estate company.
#
# Your summary should explain:
# - the objective of the project
# - key insights about the data
# - the most important findings, including a plain-language description of model performance
# - a clear recommendation or takeaway
#
# Avoid technical detail and jargon. Focus on what matters and why.

# %% [markdown]
# **1.1 Answer:**
# >- **Objective**: The main objective of the project is to predict accessed tax value of properties using different home characteristics. Predicting these values accurately could help real estate companies, agents and buyers take the hidden costs of taxes into consideration in the home buying process.
# >- **Key insights**: Through our analysis of the housing data, we found that features related to property's size and locations are the most important factors influencing its tax value
# >- **important findings**: After evaluating multiple machine learning models, we found that a Random Forest model provided the most accurate predictions. The model's predictions, on average, off by approximately $190000 from the actual accessed value. While there is a big margin or error, it represents a meaningful improvement over the simpler models.
# >- **recommendation**: Our recommendations is to examine more complex and unsual properties with the largest errors to identify opportunities to further finetune the model until we get to the point where we can deploy this model to generate ititial tax estimates for buyers.

# %% [markdown]
# ## 2. Introduction [3 points]
#
# Introduce the topic, context, and goals of your project.
#
# You may imagine that this project was completed for a **real estate company with a small in-house data science team**.
#
# Include all of the following:
#
# - Clearly introduce the topic and context of your project
# - Describe the problem you are addressing (the problem statement) and the overall motivation for solving it
# - Clearly state the objectives and goals of your analysis (as different from the motivation)

# %% [markdown]
# **2.1 Answer:**
#
# >The objective of this project is to predict a property's assessed tax value (taxvaluedollarcnt) using a collection of property characteristics such as size, location, and the number of rooms. We are working with a reduced version of the Zillow housing dataset. We are conducting this analysis for a real estate company with a small in house data science team. Providing accurate tax estimates is crucial because these costs significantly impact a buyer's purchasing decision.
# >
# >The motivation behind solving this problem is to develop a reliable tool that can estimate property taxes automatically when a listing is uploaded. Our primary goal is to build and evaluate several regression models, apply data cleaning and feature engineering, and ultimately select the best performing model to deliver accurate tax value predictions

# %% [markdown]
# ## 3. Data Description [3 points]
#
# Describe the dataset used in your analysis.
#
# Include:
# - the source of the dataset
# - the number of observations (samples) and features
# - the types of variables
# - the target variable
# - missing values or other important issues in the raw data

# %% [markdown]
# >We used a reduced version of the Zillow housing dataset from the Zillow Prize competition on Kaggle. The dataset contains 61,866 training samples and 15,467 test samples. There are 55 original features, including categorical variables (like hashottuborspa, propertycountylandusecode, and taxdelinquencyflag) and numeric variables (such as bathroomcnt, calculatedfinishedsquarefeet, and yearbuilt).
# >
# >The target variable is taxvaluedollarcnt, which represents the assessed tax value in dollars. A significant issue with the raw data is the extensive amount of missing values. Thirty three features are missing over 10% of their data, and 22 features are missing over 90% of their data, with some features like finishedsquarefeet6 having less than 1% of the values available

# %% [markdown]
# ## 4. Methodology (What you did, and why) [20 points]
#
# Focus on the **process and your reasoning**, not the results.
#
# Note: Each subsection (e.g., 4.1, 4.2, etc.) must be answered in its own Markdown cell.  Each subsection is worth 5 points.

# %% [markdown]
# ### 4.1 Analytical Framework
#
# Describe the overall framework you used to develop, compare, and evaluate your models.
#
# This section should explain the structure of your model-development process: what procedures you used, how the stages fit together, and how modeling decisions were made.
#
# > Present the detailed plots, tables, and numerical evidence supporting those decisions later in Section 5.2.
#
# Include:
#
# - how the data were used for training, validation, and final testing,
# - the primary evaluation metric you selected, such as MAE or RMSE, and why it was appropriate,
# - the procedure you used to compare alternative models, preprocessing choices, and hyperparameter settings, and
# - how validation methods, such as cross-validation, validation curves, RandomizedSearch, or Optuna, were incorporated into the model-development process.

# %% [markdown]
# **4.1 Answer:**
#
# >Our analytical framework relied on an iterative modeling workflow guided by repeated 5-fold cross-validation (with 5 repeats). The dataset was split into a training set and a held-out test set, with the test set strictly reserved for evaluating the final model.
# >
# >Our primary evaluation metric was Mean Absolute Error (MAE) because it provides a clear interpretation in actual dollars. We established baseline performance using Ridge Regression, Random Forest, and HistGradientBoosting. We then systematically evaluated preprocessing and feature engineering ideas by comparing the cross-validation MAE against the baselines. Finally, we used validation curves to identify promising hyperparameter regions and RandomizedSearchCV or GridSearchCV for focused hyperparameter tuning before evaluating the best model on the hold-out test set.

# %% [markdown]
# ### 4.2 Data Cleaning and Preprocessing
#
# Describe how you cleaned and prepared the raw data for modeling.
#
# Focus on the problems you encountered, the procedures you considered, and the reasoning behind your final preprocessing choices. Detailed plots, tables, and numerical comparisons supporting these decisions should be presented later in Section 5.2.
#
# Include:
#
# * important issues in the raw data, such as missing values, outliers, inconsistencies, or unusable features,
# * how you addressed those issues,
# * the preprocessing alternatives you considered,
# * which procedures you retained for the final analysis and why, and
# * which procedures you rejected or changed and why.

# %% [markdown]
# **4.2 Answer:**
#
# > he raw dataset contained severe missing data issues, so we dropped features that were overwhelmingly empty. For the remaining numeric features, we applied a SimpleImputer using the median strategy. This strategy was retained because it effectively fills missing values without being skewed by extreme outliers.
# >
# > We also encountered the need to scale features for our regularized linear model. We included a StandardScaler in the pipeline for Ridge Regression to standardize the predictor variables. Tree based models like Random Forest and HistGradientBoosting do not require feature scaling, so we omitted that step for them. These preprocessing steps were built directly into Scikit Learn pipelines to ensure they were fit separately within each cross validation fold, preventing data leakage.

# %% [markdown]
# ### 4.3 Feature Engineering
#
# Describe the feature transformations and new features you considered during model development.
#
# Focus on what you tried, the purpose of each change, and the reasoning behind the features you ultimately retained. Detailed evidence comparing these choices should be presented later in Section 5.2.
#
# Include:
#
# * transformations applied to existing features,
# * new features created from the available data,
# * the motivation for each transformation or new feature,
# * which features or transformations you retained and why, and
# * which features or transformations you rejected and why.

# %% [markdown]
# **4.3 Answer:**
#
# > We evaluated three main feature engineering hypotheses.
# > - First, we tried removing highly correlated features to reduce redundancy, keeping bathroomcnt and calculatedfinishedsquarefeet while dropping alternatives like calculatedbathnbr and fullbathcnt.
# > - Second, we applied a log-transformation to the target variable (taxvaluedollarcnt) using a TransformedTargetRegressor.
# > - Third, we created a new feature representing the interaction between home size and bathroom count (calculatedfinishedsquarefeet * bathroomcnt).
# >
# > We rejected the log transformation because it significantly worsened the MAE across all models. Removing correlated features slightly reduced performance for most models, so it was rejected. The size bathroom interaction greatly improved the Ridge Regression model, reducing its MAE by about $16,076, so we retained it specifically for the Ridge model.

# %% [markdown]
# ### 4.4 Model Selection
#
# Describe how you selected your model.
#
# Include:
# - models you tried and why
# - how you evaluated generalization
# - how validation results were used to compare models and hyperparameters
# - how the test set was reserved for the final evaluation of the selected model
# - any important trade-offs you considered, such as predictive performance, computational cost, interpretability, or model complexity

# %% [markdown]
# **4.4 Answer:**
#
# > We tested three baseline models: Ridge Regression, Random Forest Regressor, and HistGradientBoostingRegressor.
# > These were chosen to compare a simple linear model against more flexible tree based ensemble methods. We evaluated generalization using repeated 5-fold cross validation on the training set, holding out the test set for the final evaluation.
# >
# > Random Forest achieved the lowest validation MAE at $190,066.80, making it our top performer. We applied Sequential Feature Selection for Ridge and Feature Importance selection for the tree models, which slightly increased the error but created simpler, more interpretable models with fewer features.
# >
# > After tuning hyperparameters with RandomizedSearchCV, Random Forest remained the strongest model with the lowest tuned MAE and standard deviation, providing the best balance of predictive accuracy and stability.

# %% [markdown]
# ## 5. Results and Evaluation (What you found, and how well it worked) [16 points]
#
# Focus on **results, evidence, and interpretation**.
#
# Note: Each subsection (e.g., 5.1, 5.2, etc.) must be answered in its own Markdown cell.

# %% [markdown]
# ### 5.1 Model Performance (8 points)
#
# Present and interpret the performance of your selected final model.
#
# Include:
#
# * the final model you selected,
# * its performance on the final test set using your primary evaluation metric,
# * a practical interpretation of what that error means in the context of the project,
# * relevant supporting metrics, such as MAE, RMSE, or $R^2$,
# * a comparison with the most important alternative models, and
# * a comparison of training, validation, and final test performance to identify possible underfitting, overfitting, or discrepancies between validation and test results.
#
# Focus on the most informative results rather than reporting every metric or model considered.

# %% [markdown]
# **5.1 Answer:**
#
# > The final model selected was the tuned Random Forest Regressor using 12 selected features. It achieved a mean repeated cross-validation MAE of $188,706.61 with a standard deviation of $2,604.57. When the final model was evaluated on the held-out test set, the MAE was $189,915.54.
# >
# > In practical terms, this means that the model's estimate of a property's assessed value was off by approximately $190,000 on average. Although this is still a fairly large error in absolute dollars, Random Forest produced the most accurate results of the models evaluated in this project.
# >
# > Random Forest also performed better than the other two tuned models. HistGradientBoosting had a mean validation MAE of $190,120.77, while Ridge Regression had a much higher MAE of $231,748.09. The difference between Random Forest and HistGradientBoosting was relatively small, but Random Forest also had the lowest standard deviation across the repeated cross-validation runs, making it the strongest overall model in terms of both accuracy and stability.
# >
# > The original baseline Random Forest showed evidence of overfitting. Its training MAE was $71,471.23 compared with a validation MAE of $190,066.80, which was a large training-validation gap. After feature selection and hyperparameter tuning, the final model's validation MAE improved to $188,706.61. Its held-out test MAE of $189,915.54 was only about $1,209 higher than the validation result. The close agreement between validation and test performance suggests that the final model generalized reasonably well to unseen data, even though the original Random Forest showed a tendency to overfit.
# >
# > Overall, the tuned Random Forest provided the best combination of predictive performance, stability, and reduced model size among the models tested.

# %% [markdown]
# ### 5.2 Visualizations and Summaries (6 points)
#
# Present at least two clearly labeled visualizations or quantitative summaries that provide meaningful evidence for important modeling decisions or conclusions.
#
# Include plots, tables, or outputs from automated hyperparameter search tools that help demonstrate why particular models, preprocessing choices, features, or hyperparameter settings were retained or rejected.
#
# Insert plots and graphical outputs as clear images directly into the Markdown cell. Tables and concise quantitative summaries may be created using Markdown. Do not include code or code cells. Crop screenshots so that only the relevant material is shown, and ensure that all labels and values are readable.
#
# Each element must be clearly labeled and discussed in the text. Explain what it shows, what conclusion you draw from it, and how it supports a specific modeling decision.
#
# Notes:
#
# * You are not required to include any particular type of plot, such as a validation curve.
# * If you used automated methods such as RandomizedSearch or Optuna, include summaries, comparisons, or plots that provide evidence for your model or parameter choices.
# * Focus on the most informative evidence rather than including every plot or output produced during Milestone 2.
# * The goal is to communicate and justify your decisions, not to reproduce your experimental notebook.

# %% [markdown]
# **5.2 Answer:**
#
#
# Figure 1. Random Forest Validation Curve for Maximum Tree Depth
#
# ![Figure 1. Random Forest Validation Curve for Maximum Tree Depth](figure1_rf_max_depth_validation.png)
#
# > Figure 1 shows how Random Forest performance changed as the maximum tree depth increased. Validation MAE decreased substantially from approximately $218,696 at a depth of 5 to $189,927 at a depth of 15. Increasing the depth to 20 only improved validation MAE by about $76, while the training MAE continued to decrease substantially. At depths above 20, validation performance began to worsen.
#
# > This indicates that increasing model complexity helped up to a point, but deeper trees increasingly fit the training data without producing meaningful improvements on validation data. A maximum depth of 15 was therefore a reasonable choice because it was near the beginning of the validation-performance plateau while keeping the model less complex.
#
# Figure 2. Top 12 Random Forest Feature Importances
#
# ![Figure 2. Top 12 Random Forest Feature Importances](figure2_rf_feature_importance.png)
#
# > Figure 2 shows the 12 features with the highest importance in the Random Forest feature-selection step. The two measures of finished property size, finishedsquarefeet12 and calculatedfinishedsquarefeet, had the greatest importance. Location-related variables such as regionidzip, longitude, and latitude were also among the strongest predictors.
#
# > These results support the conclusion that property size and location contained much of the predictive information for assessed property value. The top 12 features were retained for the tree-based models. Although feature selection slightly increased Random Forest validation MAE, it reduced the feature set while preserving nearly all of the original predictive performance.
#
# Table 1. Random Forest Performance Across Model Development
#
# | Model Stage | Mean MAE |
# |---|---:|
# | Baseline Random Forest | $190,066.80 |
# | Feature-Selected Random Forest | $190,301.78 |
# | Tuned Random Forest | $188,706.61 |
# | Final Held-Out Test | $189,915.54 |
#
# > Table 1 summarizes how Random Forest performance changed throughout the modeling process. Feature selection by itself slightly increased validation MAE from $190,066.80 to $190,301.78, showing that reducing the number of features did not immediately improve accuracy. However, hyperparameter tuning reduced MAE to $188,706.61, which was better than the original baseline. The final held-out test MAE of $189,915.54 was also close to the cross-validation result, providing evidence that the final model generalized reasonably well to unseen data.

# %% [markdown]
# ### 5.3 Model Limitations (2 points)
#
# Discuss the most important limitations or weaknesses of your final model.
#
# Base your discussion on the results and analyses completed in Milestone 2. You are not required to conduct new modeling experiments for this section, although you may include an additional numerical summary or visualization if it helps clarify your conclusions.
#
# Include, as appropriate:
#
# - evidence of underfitting, overfitting, instability, or differences among - training, validation, and test performance,
# - types of observations or properties that may be especially difficult to predict,
# - plausible explanations for the model’s limitations, and
# - one or more potential changes that might improve future performance.
#
# Focus on interpreting the model’s limitations rather than merely restating its performance metrics.

# %% [markdown]
# **5.3 Answer:**
#
# > One limitation of the final Random Forest model is that the prediction error is still fairly large. The final held-out test MAE was $189,915.54, meaning that the predicted assessed property value differed from the actual value by about $190,000 on average. Although Random Forest performed better than the other models we tested, this level of error would still limit the model's use as a stand-alone valuation tool.
# >
# > The original Random Forest also showed evidence of overfitting, with a training MAE of $71,471.23 compared with a validation MAE of $190,066.80. Hyperparameter tuning reduced model complexity and improved validation performance, and the final validation MAE of $188,706.61 was close to the test MAE of $189,915.54. This suggests that the final model generalized reasonably well to the held-out data, although we did not calculate a final training MAE to determine whether some overfitting still remained.
# >
# > Another challenge is the presence of unusual and high-value properties. During the exploratory analysis, we identified extreme properties with very large square footage or assessed values and chose to retain them. These types of observations may be more difficult for the model to predict because they are less common and may not follow the same relationships as typical properties. The raw dataset also contained substantial missing data, which required many features to be removed and the remaining missing numeric values to be imputed.
# >
# > With additional time, I would analyze the properties with the largest prediction errors to determine whether certain assessed-value ranges, locations, or property types are consistently harder to predict. I would also investigate additional useful features, test more model-specific feature engineering, and compare the Random Forest with an ensemble combining Random Forest and HistGradientBoosting.

# %% [markdown]
# ## 6. Conclusion [4 points]
#
# Summarize the main findings and implications of your analysis. This section should not simply repeat the Executive Summary. It is written for a technical audience that has read the full report and should synthesize the evidence, limitations, and practical significance of your work.
#
# Include all of the following:
#
# * clearly state your main findings and explain how they address the original project objectives,
# * highlight the business or practical implications of those findings,
# * discuss the limitations and constraints of your analysis clearly and transparently,
# * suggest potential improvements or directions for future work, and
# * conclude with a final recommendation that addresses the original business objective.

# %% [markdown]
# **6.1 Answer:**
#
# > This project developed and evaluated several regression approaches for predicting a property's assessed value using characteristics from the Zillow housing dataset. Across the models evaluated, tree-based methods performed substantially better than Ridge Regression, suggesting that the relationship between property characteristics and assessed value is not completely linear. The final selected model was a tuned Random Forest using 12 selected features. It achieved a mean repeated cross-validation MAE of $188,706.61 and a held-out test MAE of $189,915.54. The close agreement between validation and test performance suggests that the final model generalized reasonably well to unseen data.
# >
# > The modeling process also showed that preprocessing and feature engineering choices were model dependent. The size-bathroom interaction substantially improved Ridge Regression, while it provided little benefit to the tree-based models. Removing highly correlated variables and log-transforming the target did not consistently improve performance. Feature selection slightly increased Random Forest error, but it reduced the model to 12 features, and subsequent hyperparameter tuning improved performance beyond the original Random Forest baseline.
# >
# > From a practical perspective, the Random Forest provides the strongest automated estimate of assessed property value among the models tested. However, an average test error of approximately $190,000 is still substantial, especially for properties at the lower end of the value distribution. The dataset also contained extensive missing values and unusual high-value or large properties, which may limit prediction quality for less common observations. These limitations mean that the model should not yet be treated as a stand-alone replacement for a full property valuation process.
# >
# > Future work should focus on analyzing the observations with the largest prediction errors to determine whether particular value ranges, locations, or property types are consistently more difficult to predict. Additional feature engineering, better use of categorical information, and ensemble approaches combining Random Forest with HistGradientBoosting could also be investigated. Based on the results of this project, the tuned Random Forest should be retained as the current best model and used as a strong baseline or supporting valuation tool while additional improvements are developed before production deployment.
